# %%
# %pip install yolov5
# %pip install tensorflow
# %pip install clearml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=DKDZ5EJ5FBD4YUDC4F2S
# %env CLEARML_API_SECRET_KEY=dyPETQn2kyIF8A6ONA0XFAR3DECeFAJIN96QgN1Ry9SPxPabPt
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=DKDZ5EJ5FBD4YUDC4F2S
# env: CLEARML_API_SECRET_KEY=dyPETQn2kyIF8A6ONA0XFAR3DECeFAJIN96QgN1Ry9SPxPabPt

# %%
# !yolov5 train --project triplefc24-yolo --training1 ---img640 --batch 16 --epochs 300 --data yolov5model-training/model-dataset/data.yaml --weights yolov5model-training/model/best.pt --cache
# Out:
# requirements: C:\Users\fifag\AppData\Local\Programs\Python\Python312\Lib\site-packages\requirements.txt not found, check failed.
# ClearML Task: created new task id=4b34885c9c1c41d48583f63d0684c5d0
# 2024-05-21 14:38:06,810 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/f1af169621f64f048e1e8536d8930252/experiments/4b34885c9c1c41d48583f63d0684c5d0/output/log
# ...
